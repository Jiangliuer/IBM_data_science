# %% [markdown]
# # pandas load data to database

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
connect = create_engine("mysql+pymysql://root:alpha123@localhost:3306/chicago?charset=utf8mb4", echo=False)

# %%
# read data
df_crime = pd.read_csv("../2.IBM_data_science/data/Chicago_Crime_Data-v2.csv")
df_school = pd.read_csv("../2.IBM_data_science/data/Chicago_Public_Schools_-_Progress_Report_Cards__2011-2012-v3.csv")
df_census = pd.read_csv("../2.IBM_data_science/data/Census_Data_-_Selected_socioeconomic_indicators_in_Chicago__2008___2012-v2.csv")

# %%
df_crime.rename(columns={col: col.strip() for col in df_crime.columns}, inplace=True)
df_school.rename(columns={col: col.strip() for col in df_school.columns}, inplace=True)
df_census.rename(columns={col: col.strip() for col in df_census.columns}, inplace=True)

# %%
df_crime.head(2)
# Out:
#         ID CASE_NUMBER                    DATE                     BLOCK IUCR  \
# 0  3512276    HK587712  08/28/2004 05:50:56 PM        047XX S KEDZIE AVE  890
# 1  3406613    HK456306  06/26/2004 12:40:00 PM  009XX N CENTRAL PARK AVE  820
#
#   PRIMARY_TYPE     DESCRIPTION LOCATION_DESCRIPTION  ARREST  DOMESTIC  \
# 0        THEFT   FROM BUILDING   SMALL RETAIL STORE   False     False
# 1        THEFT  $500 AND UNDER                OTHER   False     False
#
#                ...                WARD  COMMUNITY_AREA_NUMBER  FBICODE  \
# 0              ...                14.0                   58.0        6
# 1              ...                27.0                   23.0        6
#
#    X_COORDINATE Y_COORDINATE  YEAR               UPDATEDON   LATITUDE  \
# 0     1155838.0    1873050.0  2004  02/10/2018 03:50:01 PM  41.807441
# 1     1152206.0    1906127.0  2004  02/28/2018 03:56:25 PM  41.898280
#
#    LONGITUDE                       LOCATION
# ...

# %%
df_school.head(2)
# Out:
#    School ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
#
#   Elementary, Middle, or High School          Street Address     City State  \
# 0                                 ES        615 W Kemper Pl   Chicago    IL
# 1                                 ES  7511 S South Shore Dr   Chicago    IL
#
#    ZIP Code    Phone Number  \
# 0     60614  (773) 534-5720
# 1     60649  (773) 535-6650
#
#                                                 Link  \
# 0  http://schoolreports.cps.edu/SchoolProgressRep...
# 1  http://schoolreports.cps.edu/SchoolProgressRep...
#
#                 Network Manager             ...               \
# 0  Fullerton Elementary Network             ...
# 1     Skyway Elementary Network             ...
#
#   Freshman on Track Rate % X_COORDINATE Y_COORDINATE   Latitude  Longitude  \
# ...

# %%
df_census.head(2)
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER_CAPITA_INCOME  HARDSHIP_INDEX
# 0                              27.5              23939            39.0
# 1                              38.5              23040            46.0

# %%
df_crime.to_sql(name="CHICAGO_CRIME_DATA", con=connect, if_exists="replace")
df_school.to_sql(name="CHICAGO_PUBLIC_SCHOOLS", con=connect, if_exists="replace")
df_census.to_sql(name="CENSUS_DATA", con=connect, if_exists="replace")

# %% [markdown]
# # sql in jupyter notebook

# %%
# !pip install ipython-sql

# %load_ext sql
# Out:
# Looking in indexes: http://mirrors.aliyun.com/pypi/simple/
# ...
#      |████████████████████████████████| 6.0 MB 572 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 40 kB 33.6 MB/s eta 0:00:01
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.13-cp36-cp36m-macosx_10_9_x86_64.whl size=1171149 sha256=1c52d9108a5608cde205be91964d8abdececc45c9ae3477f53e20624b6ccabf2
#   Stored in directory: /Users/xiaohui/Library/Caches/pip/wheels/23/d1/49/85a7b1989782d23ddb6235184dde52f64d0529745cfbb33c80
# Successfully built sqlalchemy
# ...

# %%
# %sql mysql+pymysql://root:alpha123@localhost:3306/chicago?charset=utf8
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pymysql/cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)
# 'Connected: root@chicago'

# %%
# %sql show databases;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 5 rows affected.
# [('chicago',),
#  ('information_schema',),
#  ('mysql',),
#  ('performance_schema',),
#  ('sys',)]

# %%
# %sql use chicago;
# %sql show tables;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 0 rows affected.
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 3 rows affected.
# [('CENSUS_DATA',), ('CHICAGO_CRIME_DATA',), ('CHICAGO_PUBLIC_SCHOOLS',)]

# %%
# %sql select * from census_data;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 78 rows affected.
# [(0, 1.0, 'Rogers Park', 7.7, 23.6, 8.7, 18.2, 27.5, 23939, 39.0),
#  (1, 2.0, 'West Ridge', 7.8, 17.2, 8.8, 20.8, 38.5, 23040, 46.0),
#  (2, 3.0, 'Uptown', 3.8, 24.0, 8.9, 11.8, 22.2, 35787, 20.0),
#  (3, 4.0, 'Lincoln Square', 3.4, 10.9, 8.2, 13.4, 25.5, 37524, 17.0),
#  (4, 5.0, 'North Center', 0.3, 7.5, 5.2, 4.5, 26.2, 57123, 6.0),
#  (5, 6.0, 'Lake View', 1.1, 11.4, 4.7, 2.6, 17.0, 60058, 5.0),
#  (6, 7.0, 'Lincoln Park', 0.8, 12.3, 5.1, 3.6, 21.5, 71551, 2.0),
#  (7, 8.0, 'Near North Side', 1.9, 12.9, 7.0, 2.5, 22.6, 88669, 1.0),
#  (8, 9.0, 'Edison Park', 1.1, 3.3, 6.5, 7.4, 35.3, 40959, 8.0),
#  (9, 10.0, 'Norwood Park', 2.0, 5.4, 9.0, 11.5, 39.5, 32875, 21.0),
#  (10, 11.0, 'Jefferson Park', 2.7, 8.6, 12.4, 13.4, 35.5, 27751, 25.0),
#  (11, 12.0, 'Forest Glen', 1.1, 7.5, 6.8, 4.9, 40.5, 44164, 11.0),
#  (12, 13.0, 'North Park', 3.9, 13.2, 9.9, 14.4, 39.0, 26576, 33.0),
# ...

# %%
table_name = ["CENSUS_DATA", "CHICAGO_CRIME_DATA", "CHICAGO_PUBLIC_SCHOOLS"]
for table in table_name:
    print(table.lower())
# Out:
# census_data
# chicago_crime_data
# chicago_public_schools

# %% [markdown]
# # write and excute query
# Problem 1: Find the total number of crimes recorded in the crime table.

# %%
# %%sql
# select count(*) from chicago_crime_data;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 1 rows affected.
# [(533,)]

# %% [markdown]
# Problem 2: Retrieve first 10 rows from the CRIME table.

# %%
# %%sql
# select * from chicago_crime_data limit 10
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 10 rows affected.
# [(0, 3512276, 'HK587712', '08/28/2004 05:50:56 PM', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 0, 0, 911, 9, 14.0, 58.0, '6', 1155838.0, 1873050.0, 2004, '02/10/2018 03:50:01 PM', 41.8074405, -87.70395585, '(41.8074405, -87.703955849)'),
#  (1, 3406613, 'HK456306', '06/26/2004 12:40:00 PM', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 0, 0, 1112, 11, 27.0, 23.0, '6', 1152206.0, 1906127.0, 2004, '02/28/2018 03:56:25 PM', 41.89827996, -87.71640551, '(41.898279962, -87.716405505)'),
#  (2, 8002131, 'HT233595', '04/04/2011 05:45:00 AM', '043XX S WABASH AVE', '820', 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 0, 0, 221, 2, 3.0, 38.0, '6', 1177436.0, 1876313.0, 2011, '02/10/2018 03:50:01 PM', 41.81593313, -87.62464213, '(41.815933131, -87.624642127)'),
# ...

# %% [markdown]
# Problem 3: How many crimes involve an arrest.

# %%
# %%sql
# select count(*) from chicago_crime_data where ARREST=1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 1 rows affected.
# [(163,)]

# %% [markdown]
# Problem 4: Which unique types of crimes (e.g. THEFT) have been recorded at a GAS STATION locations?

# %%
# %%sql
# select distinct(primary_type),location_description from chicago_crime_data where location_description='GAS STATION';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 4 rows affected.
# [('THEFT', 'GAS STATION'),
#  ('NARCOTICS', 'GAS STATION'),
#  ('ROBBERY', 'GAS STATION'),
#  ('CRIMINAL TRESPASS', 'GAS STATION')]

# %% [markdown]
# Problem 5: In the CENUS_DATA table list all community areas whose names start with the letter ‘B’.

# %%
# %%sql
# select community_area_name from census_data where community_area_name like 'B%';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 5 rows affected.
# [('Belmont Cragin',),
#  ('Burnside',),
#  ('Brighton Park',),
#  ('Bridgeport',),
#  ('Beverly',)]

# %%
# %%sql
# select * from chicago_public_schools limit 2;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 2 rows affected.
# [(0, 610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl ', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Strong', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...

# %% [markdown]
# Problem 6: List the schools in community areas 10 to 15 that are healthy school certified.

# %%
# %%sql
# select name_of_school from chicago_public_schools where community_area_number between 10 and 15
# and healthy_school_certified='Yes';
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 1 rows affected.
# [('Rufus M Hitch Elementary School',)]

# %% [markdown]
# Problem 7: What is the average school Safety Score?

# %%
# %%sql
# select avg(safety_score) as safety_score_avg from chicago_public_schools;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 1 rows affected.
# [(49.50487329434698,)]

# %% [markdown]
# Problem 8: Find the top 5 Community Areas by average College Enrollment [number of students].

# %%
# %%sql
# select community_area_name,college_enrollment_avg from
# (select community_area_name,avg(college_enrollment) as college_enrollment_avg from chicago_public_schools
#  group by community_area_name) A
# order by college_enrollment_avg desc limit 5;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 5 rows affected.
# [('ARCHER HEIGHTS', Decimal('2411.5000')),
#  ('MONTCLARE', Decimal('1317.0000')),
#  ('WEST ELSDON', Decimal('1233.3333')),
#  ('BRIGHTON PARK', Decimal('1205.8750')),
#  ('BELMONT CRAGIN', Decimal('1198.8333'))]

# %% [markdown]
# Problem 9: Use a sub-query to determine which Community Area has the least value for school Safety Score?

# %%
# %%sql
# select community_area_name,safety_score  from chicago_public_schools where
#  safety_score=(select min(safety_score) from chicago_public_schools);
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 1 rows affected.
# [('WASHINGTON PARK', 1.0)]

# %% [markdown]
# Problem 10: [Without using an explicit JOIN operator] Find the Per Capita Income of the Community Area which has a school Safety Score of 1.

# %%
# %%sql
# select S.community_area_name,S.safety_score,C.per_capita_income from census_data as C, chicago_public_schools as S
# where C.community_area_name = S.community_area_name and S.safety_score=1;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 1 rows affected.
# [('WASHINGTON PARK', 1.0, 13785)]

# %%
# %%sql
# select community_area_name,per_capita_income from census_data where community_area_name in
# (select community_area_name from chicago_public_schools where safety_score=1)
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 1 rows affected.
# [('Washington Park', 13785)]

# %%
# %%sql
# select * from chicago_public_schools limit 3;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/chicago?charset=utf8
# 3 rows affected.
# [(0, 610038, 'Abraham Lincoln Elementary School', 'ES', '615 W Kemper Pl ', 'Chicago', 'IL', 60614, '(773) 534-5720', 'http://schoolreports.cps.edu/SchoolProgressReport_Eng/Spring2011Eng_610038.pdf', 'Fullerton Elementary Network', 'NORTH-NORTHWEST SIDE COLLABORATIVE', 'No', 'Standard', 'Not on Probation', 'Level 1', 'Yes', 'Very Strong', 99.0, 'Very Strong', '99', 'Strong', 74.0, 'Strong', 66.0, 'Strong', '65', 'Strong', '70', 'Strong', '56', 'Average', '47', '96.00%', 2.0, '96.40%', '95.80%', '80.1', '43.3', '89.6', '84.9', '60.7', '62.6', '81.9', '85.2', '52', '62.4', '66.3', '77.9', 69.7, 64.4, 0.2, 0.9, 'Yellow', 'Green', '67.1', '54.5', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 'NDA', 813, 33, 'NDA', 1171699.458, 1915829.428, 41.92449696, -87.64452163, 7, 'LINCOLN PARK', 43, 18, '(41.92449696, -87.64452163)'),
# ...
